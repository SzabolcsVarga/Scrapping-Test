# %% [markdown]
# # Emag Web Scraping

# %% [markdown]
# ## Import packages

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Request URL with Items

# %%
url = "https://www.emag.ro/search-by-filters-with-redirect"

# %% [markdown]
# ## Headers

# %%
querystring = {'source_id':'7','templates[]':'full','is_eab344':'false','sort[popularity_total_orders_v1]':'desc','listing_display_id':'2','page[limit]':'100','page[offset]':'0','fields[items][image_gallery][fashion][limit]':'2','fields[items][image][resized_images]':'1','fields[items][resized_images]':'200x200,350x350,720x720','fields[items][flags]':'1','fields[items][offer][buying_options]':'1','fields[items][offer][flags]':'1','fields[items][offer][bundles]':'1','fields[items][offer][gifts]':'1','fields[items][characteristics]':'listing','fields[quick_filters]':'1','search_fraze':'','search_key':'','filters[department][]':'pc-periferice-software','filters[subdepartment][]':'componente','filters[category][]':'37','filters[shop_id]':'1','filters[page_type]':'category'}
headers ={
    'Referer': 'https://www.emag.ro/placi_video/c?tree_ref=0&ref=cat_tree_37',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36',
    'accept': 'application/json',
    'sec-ch-ua': "'Chromium';v='104', ' Not A;Brand';v='99', 'Google Chrome';v='104'",
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': "'Windows'",
    'x-app-module': 'ChangePerPage',
    'x-app-name': 'photon-static',
    'x-request-source': 'www',
    'x-requested-with': 'XMLHttpRequest'}

# %% [markdown]
# ## Sending and Getting the respoonse

# %%
response = requests.request("GET", url, headers=headers, params=querystring)

# %% [markdown]
# ## Saving the results as a json data

# %%
data_list=response.json()

# %%
products=data_list['data']['items']

# %%
df=pd.json_normalize(products)

# %%
df
# Out:
#           id                                               name  \
# 0   39905190  Placa video Gigabyte GeForce® RTX™ 3060 EAGLE ...
# 1   34545060  Placa video ASUS Phoenix GeForce® GTX 1650 OC,...
# 2    5802559  Placa video Sapphire Radeon RX 550 Pulse, 4GB ...
# 3   43320038  Placa video Gigabyte GeForce® RTX™ 3050 GAMING...
# 4   38812061  Placa video Gigabyte GeForce® RTX™ 3060 GAMING...
# ..       ...                                                ...
# 95  43687825  Placa video ASUS Dual GeForce RTX™ 2060 EVO, 1...
# 96  39843260  Placa video ASUS ROG Strix GeForce® RTX™ 3060 ...
# 97  42880256  Placa video PowerColor RX 550, 4GB GDDR5, 128-bit
# 98  34095035  Placa video PNY GeForce® RTX™ 3060 Ti XLR8 Gam...
# 99  32446038  Placa video ASUS TUF GAMING GeForce RTX™ 3090 ...
#
#    part_number_key  multiple_offers_count  used_offers_count  offers_count  \
# 0        DDCFDPMBM                      8                  0             8
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'part_number_key', 'multiple_offers_count',
#        'used_offers_count', 'offers_count', 'multiple_min_price',
#        'used_min_price', 'quick_uri', 'sef_name',
#        ...
#        'family.id', 'family.name', 'family.sef_name', 'family.labels.short',
#        'family.labels.detailed', 'family.icon.original',
#        'family.characteristics', 'offer.flags.has_performant_price_index',
#        'offer.flags.show_price_index_details', 'offer.price_index'],
#       dtype='object', length=227)

# %%
import requests

cookies = {
    'EMAGVISITOR': 'a%3A1%3A%7Bs%3A7%3A%22user_id%22%3Bi%3A2107170171004466800%3B%7D',
    'ltuid': '1615656571.448-d021d16ec66485965ceaf769466ee74b24475645',
    'EMAGUUID': '1615656571-719791068-75087.148',
    '_pdr_internal': 'GA1.2.1780165619.1615656571',
    '_pin_unauth': 'dWlkPVpUQmtaVGMxT0RNdFlUUmpaQzAwT1dZeUxXSTVaR1l0TXpNeFpUTXhPVEUxWkRJMg',
    'eab661': 'b',
    'eab664': 'a',
    'eab668': 'b',
    'eab672': 'na',
    'eab659': 'c',
    'eab681': 'b',
    'eab670': 'b',
    'eab654': 'b',
    'listingResetView': '1',
    'eab708': 'b',
    'eab710': 'b',
    '_gcl_au': '1.1.813042063.1656840658',
    'site_version_11': 'not_mobile',
    'eab750': 'a',
    'eab712': 'b',
    'eab753': 'b',
    'eab749': 'a',
    'eab757': 'b',
    'eab733': 'c',
    'eab728': 'a',
    'eab762': 'b',
    'eab758': 'a',
    'eab716': 'a',
    'gmsavings-2587639': '{"v":{"v":0,"l":1},"t":1661151356977,"e":"14d"}',
    'eab763': 'a',
    'eab773': 'b',
    'eab764': 'a',
    'delivery_locality_id': '6409',
    'AID': '95b89fd4c3ca6bdebeea484cfdfc9b78ad88e9f60afd5e4580ed7568d8df9aa7',
    'eab781': 'c',
    'EMAGROSESSID': 'o1fbsatbokp0koovc7d5l4kloo',
    'sapi-token': '...',
    'cart_summary': '%7B%22t%22%3A1662057334%2C%22b%22%3A1%2C%22p%22%3A47.51%2C%22bfc%22%3A0%2C%22line%22%3A%7B%221%22%3A1%7D%7D',
    'eab_allocation': '',
    'listingPerPage': '',
    '_pdr_view_id': '1662057554-86808.472-495944123',
    'listingDisplayId': '2',
}

headers = {
    'Accept-Language': 'ro-RO,ro;q=0.9,en-US;q=0.8,en;q=0.7,ru;q=0.6,hu;q=0.5,it;q=0.4',
    'Connection': 'keep-alive',
    # Requests sorts cookies= alphabetically
    # 'Cookie': 'EMAGVISITOR=a%3A1%3A%7Bs%3A7%3A%22user_id%22%3Bi%3A2107170171004466800%3B%7D; ltuid=1615656571.448-d021d16ec66485965ceaf769466ee74b24475645; EMAGUUID=1615656571-719791068-75087.148; _pdr_internal=GA1.2.1780165619.1615656571; _pin_unauth=dWlkPVpUQmtaVGMxT0RNdFlUUmpaQzAwT1dZeUxXSTVaR1l0TXpNeFpUTXhPVEUxWkRJMg; web4_ga=GA1.1.1010383369.1615656873; G_ENABLED_IDPS=google; pdr_user_id=1e54637f711e714f4c8a60a92801867b; user_token=576e68096f9aab3b4996234c9ee2111c; customer_has_orders=1; sr=1920x1040; vp=1920x937; _ga=GA1.1.1780165619.1615656571; user_remember=%DB%11b%C5dy%B9%BA%A4%928%CA%A9%3D%ECl%DBqk%A7%DE%8D%1E%E4%3EQ%CF%7Fg%15%EFk%2FM%D9%F0%7Dm.%AAUg%C6%9F%DFW%2A%3C%8EXS%10%10%85%29%60%01%E1%EF4%03%A3%16g%9E%FE%01%3B4Us%BDz%EC%EF%A2%E1%C4%3F%1E%BC%E7n%D6%3C%C9%C8%F3%7B%40%84V%2FpiK%A8%15t%7D%07%EC%A8%D5%3E%99%3C%11rt6%EC%C8%E8e4x%E6%A3%D3%85%99%F3F%1A%1F%09%D0%7C%FB%40%FE%95Nn%8Fw%26%A8D%26%A6%9C%AD%91%EAO%B4%D1%F5%FB%81%94%5Dn%7C%99%60%95%D6%A9%8Aq%0D-%EE%E4%60; _ga_HXNW3QDT0J=GS1.1.1624534267.6.0.1624534267.60; web4_ga_HXNW3QDT0J=GS1.1.1624871176.37.1.1624871554.40; FPID=FPID2.2.BJSY9x%2BGDUoE%2Bwx8MMZZfdnrAjjVw0jE2AXaTcd%2BT7U%3D.1615656873; cto_bundle=es4uhl9qbkZkMVElMkJXQTFWUk0wdjdCbTJQQTdjWEdSclR3enNTSjVrQjg1MGRiUEJSWUJQeTkzNzZyWjhOc2FReUNaTlN4QlU2Q0VPOXpYQXllV3A1M21XMWYzV3RQVlpTMTN0OFFDMWpCWnZjSjdrdWlhdkZMT0dqZ0ZOSFUzemFSNUxRMjNvVGtnYkhYSyUyRkFUYXRZMUtoSjJ3JTNEJTNE; _ga_JJCSV4C7C3=GS1.1.1632846191.6.0.1632847755.0; _uetvid=cf50f670842111eb98639bcdb2fb90d8; _derived_epik=dj0yJnU9STE1elJSempZQzhnZUdiYjA2LXgwR2JxU0YtRk5pYWgmbj12d1J5U3ItcXpUcE5MR1VvS1V1LVN3Jm09MSZ0PUFBQUFBR0ZUUjR3JnJtPTEmcnQ9QUFBQUFHRlRSNHc; web4_ga_JJCSV4C7C3=GS1.1.1632845440.7.1.1632847968.0; web4_ga_123456789=GS1.1.1632845441.5.1.1632847968.0; udp=eAGNkUEKwzAMBP%2BiF1iWnMTKa1Jy8aFQSG%2FBf6%2BtpFUI1PgkrzA7WmmRIHuSiPMiLPsmKLDCrBVr9QLv7WyEs%2FF81QcLEDLBnIRHVw3wNHhAEV59Dwd09Rc6NplzLljqwfIdiy60sRjQSGU8b0q5gXu4haH5j7gkMFJsph0Mk4QCmVQqxx6qv1Oj0%2B393fE1XRJ%2FGUKpNPZQv7f%2BZY3T0MyK0dKV006mCjV%2FAE60mTI%3D; GKD=%96%B8%B0%9F%A1%BC%8D%AD%92%B9%95%92%B0%BF%88%9A%90%85%99%B6%95%DB%AD%D4%A0%BC%88r%93%83%A1%DA%BC%C2%98%DD%9C%95%8D%B9%96%CB%AC%A8; eab581=b; eab616=b; eab608=a; eab636=b; eab629=c; eab661=b; eab664=a; eab668=b; eab672=na; eab659=c; eab681=b; eab670=b; eab654=b; listingResetView=1; eab708=b; eab710=b; _gcl_au=1.1.813042063.1656840658; site_version_11=not_mobile; eab750=a; eab712=b; eab753=b; eab749=a; eab757=b; eab733=c; eab728=a; eab762=b; eab758=a; eab716=a; gmsavings-2587639={"v":{"v":0,"l":1},"t":1661151356977,"e":"14d"}; eab763=a; eab773=b; eab764=a; delivery_locality_id=6409; AID=95b89fd4c3ca6bdebeea484cfdfc9b78ad88e9f60afd5e4580ed7568d8df9aa7; eab781=c; EMAGROSESSID=o1fbsatbokp0koovc7d5l4kloo; sapi-token=...; cart_summary=%7B%22t%22%3A1662057334%2C%22b%22%3A1%2C%22p%22%3A47.51%2C%22bfc%22%3A0%2C%22line%22%3A%7B%221%22%3A1%7D%7D; eab_allocation=; listingPerPage=30; _pdr_view_id=1662057554-86808.472-495944123; listingDisplayId=2',
    'Referer': 'https://www.emag.ro/televizoare/filter/claritate-imagine-f9180,4k-v-8182405/c?ref=list',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36',
    'accept': 'application/json',
    'sec-ch-ua': '"Chromium";v="104", " Not A;Brand";v="99", "Google Chrome";v="104"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'x-app-module': 'ViewTypeChange',
    'x-app-name': 'photon-static',
    'x-request-source': 'www',
    'x-requested-with': 'XMLHttpRequest',
}

params = {
    'source_id': '7',
    'templates[]': 'full',
    'is_eab344': 'false',
    'sort[popularity_total_orders_v1]': 'desc',
    'listing_display_id': '2',
    'page[limit]': '100',
    'page[offset]': '0',
    'fields[items][image_gallery][fashion][limit]': '2',
    'fields[items][image][resized_images]': '1',
    'fields[items][resized_images]': '200x200,350x350,720x720',
    'fields[items][flags]': '1',
    'fields[items][offer][buying_options]': '1',
    'fields[items][offer][flags]': '1',
    'fields[items][offer][bundles]': '1',
    'fields[items][offer][gifts]': '1',
    'fields[items][characteristics]': 'listing',
    'fields[quick_filters]': '1',
    'search_fraze': '',
    'search_key': '',
    'filters[custom_filter][9180][]': '-8182405',
    'filters[department][]': 'tv-audio-video-foto',
    'filters[subdepartment][]': 'televizoare-accesorii',
    'filters[category][]': '492',
    'filters[shop_id]': '1',
    'filters[page_type]': 'category',
    'ref': 'grid',
}

response = requests.get('https://www.emag.ro/search-by-filters-with-redirect', params=params, cookies=cookies, headers=headers)

# %%
tv_json=response.json()

# %%
tv_list=tv_json['data']['items']

# %%
tv_df=pd.json_normalize(tv_list)

# %%
len(tv_df)
# Out:
# 100

# %%
list(tv_df.columns)
# Out:
# ['id',
#  'name',
#  'part_number_key',
#  'multiple_offers_count',
#  'used_offers_count',
#  'offers_count',
#  'multiple_min_price',
#  'used_min_price',
#  'quick_uri',
#  'sef_name',
#  'availability_key',
#  'used_offer_id_having_min_price',
#  'added_to_favorites_count',
#  'predecessor_model',
#  'category.id',
#  'category.name',
#  'category.sef_name',
#  'category.display_type',
#  'category.department.id',
#  'category.department.name',
#  'category.department.sef_name',
#  'category.subdepartment.id',
#  'category.subdepartment.name',
#  'category.subdepartment.sef_name',
#  'category.trail',
#  'category.listing_id',
#  'category.english_name',
#  'category.configurator.link',
#  'category.configurator.text',
#  'category.configurator.new',
#  'category.configurator.ref',
#  'category.configurator.url.path',
#  'category.configurator.url.desktop_base',
#  'category.configurator.url.mobile_base',
#  'category.configurator.icon',
#  'category.configurator.headline',
# ...

# %%
cropped_tv=tv_df[['name','offer.price.current','category.name','part_number_key','offer.price.current',
 'offer.price.is_min',
 'offer.price.is_max',
 'offer.price.legal',
 'offer.price.prefix',
 'offer.price.suffix',
 'offer.price.is_visible',
 'offer.price.discount.type',
 'offer.price.discount.absolute',
 'offer.price.discount.percent',
 'offer.price.discount.is_special',
 'offer.price.discount.is_visible',
 'offer.price.discount.is_restricted_from_view',
 'offer.price.discount.is_max',
 'offer.price.discount.label',
 'offer.price.discount.labeled_as_discount',
 'offer.price.currency.id',
 'offer.price.currency.name.default',
 'offer.price.currency.name.display',
 'offer.price.net',
 'offer.price.recommended_retail_price.amount',
 'offer.price.recommended_retail_price.is_visible',
 'offer.price.recommended_retail_price.label',
 'offer.price.recommended_retail_price.tooltip',
 'offer.price.lowest_price_30_days.amount',
 'offer.price.lowest_price_30_days.is_visible',
 'offer.price.lowest_price_30_days.tooltip',
 'offer.price.initial']]

# %%
cropped_tv
# Out:
#                                                  name  offer.price.current  \
# 0   Televizor Samsung 43AU7172, 108 cm, Smart, 4K ...              1630.29
# 1   Televizor Samsung 55TU7092, 138 cm, Smart, 4K ...              2060.28
# 2   Televizor LG 50UP75003LF, 126 cm, Smart, 4K Ul...              1699.99
# 3   Televizor LG 43NANO773PA, 108 cm, Smart, 4K Ul...              1699.99
# 4   Televizor Samsung 43TU7092, 108 cm, Smart, 4K ...              1649.99
# ..                                                ...                  ...
# 95  Televizor Smart Tech SMT50S10UC2U2G1, 126 cm, ...              1399.99
# 96  Televizor Samsung QLED 55Q70B, 138 cm, Smart, ...              3999.90
# 97  Televizor Samsung Neo QLED 55QN85B, 138 cm, Sm...              5799.99
# 98  Televizor Samsung QLED 75Q95T, 189 cm, Smart, ...              7999.99
# 99  Televizor Horizon 55HL7530U, 139 cm, Smart, 4K...              1619.00
#
# ...
